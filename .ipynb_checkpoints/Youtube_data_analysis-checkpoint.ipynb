# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.read_csv(r"C:\Users\mrina\Data Analytics\text-data-analysis-youtube\data-set-yt\Youtube_project_shan_singh_Udemy\UScomments.csv")
# Out:
#   Cell In[1], line 1
#     pd.read_csv("C:\Users\mrina\Data Analytics\text-data-analysis-youtube\data-set-yt\Youtube_project_shan_singh_Udemy\UScomments.csv")
#                 ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
